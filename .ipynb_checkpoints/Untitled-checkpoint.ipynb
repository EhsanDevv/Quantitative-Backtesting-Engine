# %%
import requests
import json

# %%
HEADERS={
    "APCA-API-KEY-ID" : 'PK3UVNMDWPMI4KBXXHCGGJF4JX',
    "APCA-API-SECRET-KEY" : '3P9JtQyFhU6HEazeq3yEsEcZkdrH67kxDNMpTne8QDsM'
}

BASE_URL = 'https://data.alpaca.markets/v2'
Modified_URL = f"{BASE_URL}/stocks/SPY/quotes/latest"


response = requests.get(
    Modified_URL,
    headers=HEADERS
)

data=response.json()
# print(json.dumps(data,indent=4))

print(f"Asking price: {data["quote"]["ap"]}")
print(f"Bidding price: {data["quote"]["bp"]}")
# Out:
# Asking price: 725.81
# Bidding price: 725.77
